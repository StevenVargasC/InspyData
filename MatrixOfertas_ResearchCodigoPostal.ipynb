# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
dfRepresentantes = pd.read_csv('DatosSitioWeb/tablas relacionadas/representantes.csv')

# %%
dfProveedores = pd.read_csv('DatosSitioWeb/tablas relacionadas/proveedores2.csv', dtype={'codigo_postal': 'string'} )

# %%
dfConsorcios = pd.read_csv('DatosSitioWeb/tablas relacionadas/consorcios.csv')

# %%
dfOfertas = pd.read_csv('DatosSitioWeb/tablas relacionadas/ofertas.csv')

# %%
dfLineasOfertadas = pd.read_csv('DatosSitioWeb/tablas relacionadas/lineasofertadas.csv')

# %%
dfCodigoPostal = pd.read_csv('DatosSitioWeb/out/MatrixCodigoPostalCR2024.csv', dtype={'Codigo Postal': 'string'})

# %%
dfProveedores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41484 entries, 0 to 41483
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   cedula_proveedor    41484 non-null  int64
#  1   nombre_proveedor    41484 non-null  object
#  2   tipo_proveedor      41484 non-null  object
#  3   tamano_proveedor    41484 non-null  object
#  4   fecha_constitucion  20125 non-null  object
#  5   fecha_expiracion    19744 non-null  object
#  6   direccion           41478 non-null  object
#  7   codigo_postal       40462 non-null  string
#  8   provincia           40418 non-null  object
#  9   canton              40381 non-null  object
#  10  distrito            40339 non-null  object
# dtypes: int64(1), object(9), string(1)
# memory usage: 3.5+ MB

# %%
dfCodigoPostal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     490 non-null    int64
#  1   Provincia      490 non-null    object
#  2   Canton         490 non-null    object
#  3   Distrito       490 non-null    object
#  4   Codigo Postal  490 non-null    string
# dtypes: int64(1), object(3), string(1)
# memory usage: 19.3+ KB

# %%
dfCompare = pd.merge(dfProveedores, dfCodigoPostal, left_on= ['codigo_postal'],
right_on= ['Codigo Postal'], how="left")
dfCompare
# Out:
#        cedula_proveedor                                   nombre_proveedor  \
# 0            3002667850  ASOCIACION COSTARRICENCE PARA EL ESTUDIO E INT...
# 1            3101654585                   GRUPO ALFA NOVA SOCIEDAD ANONIMA
# 2             304260976                       TOMAS ADOLFO BRENES MADRIGAL
# 3            3102615222                     THE TRAVELSHOP CENTER LIMITADA
# 4            3101215441     DEPOSITO IRAZU LOS HEREDIANOS SOCIEDAD ANONIMA
# ...                 ...                                                ...
# 41479         117830843                        STEVEN ALBERTO MONTERO RUIZ
# 41480         113300795                           ANGIE VANESSA ARIAS SOTO
# 41481        3101657980            TOTAL PARTS GUANACASTE SOCIEDAD ANONIMA
# 41482         114440080                   MELISSA EDITH VALVERDE HERNANDEZ
# 41483        3006495261                               FUNDACION MENTE SANA
#
#           tipo_proveedor  tamano_proveedor fecha_constitucion  \
# ...

# %%
dfCompare[dfCompare["Codigo Postal"].isnull()]
# Out:
#        cedula_proveedor                         nombre_proveedor  \
# 32           9000000362           IMCARD S A DE CAPITAL VARIABLE
# 60           9000000203              SUMINISTROS ELECTRICOS S.A.
# 92           9000000382           SEMEX SOCIEDAD ANONIMA DE C.V.
# 638          9000000183      INTERNATIONAL ELECTRICAL SALES CORP
# 1020         3012719874                         ARTEGRAFIKO CORP
# ...                 ...                                      ...
# 41412        9000010437  Soluciones Médicas Comercial S.A de C.V
# 41418        9000010418               Coyne Public Relations LLC
# 41427      186200179726              JESUS ANTONIO TOVAR MARQUEZ
# 41434        9000009304                             MINESOFT LTD
# 41476        9000010479                           TRAVEL-INSIGHT
#
#             tipo_proveedor  tamano_proveedor fecha_constitucion  \
# 32     Extranjero Jurídico            Grande                NaN
# ...
